# %%
import torch
import pickle
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
import numpy as np
import pandas as pd
from numpy import savetxt, loadtxt
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, global_mean_pool
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
from sklearn.metrics import precision_score, recall_score, f1_score
from torch.nn import Linear, BatchNorm1d
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.layers import Input, Concatenate, Reshape, Conv1D, Flatten, Dense, Dropout, MultiHeadAttention, LayerNormalization, Add
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.sequence import pad_sequences
import tensorflow as tf

# %% [markdown]
# # Hàm Load Dữ liệu

# %%
import pandas as pd
import numpy as np
from numpy import savetxt, loadtxt

def load_dataset(label_count):
    # Tải dữ liệu từ file CSV
    data = pd.read_csv("DATASET/multilabel_BILSTM_BERT.csv", index_col=False)
    data = data.drop(columns='Unnamed: 0', axis=1)

    # Các cột nhãn
    label_columns = ['Other', 'access_control', 'arithmetic', 'denial_service',
                     'front_running', 'reentrancy', 'time_manipulation',
                     'unchecked_low_calls']

    if label_count > len(label_columns):
        raise ValueError("Label count exceeds the available labels")

    selected_labels = label_columns[:label_count]

    for column in label_columns:
        data[column] = data[column].apply(lambda x: 1 if x != 0 else 0)

    # Lấy số lượng hàng dữ liệu là 39645
    data = data.iloc[:39645]

    # Chia tập dữ liệu thành tập huấn luyện và tập kiểm tra
    total_rows = len(data)
    split_point = int(0.8 * total_rows)
    df_train = data.iloc[:split_point]
    df_test = data.iloc[split_point:]
    features_source_train =  np.loadtxt("DATASET/split_train.csv", delimiter=',')
    features_source_test = np.loadtxt("DATASET/split_test.csv", delimiter=',')
    X_train_source = np.array(features_source_train)
    X_test_source = np.array(features_source_test)
    print("Load Features codeBERT success!!")
    # Lấy các đặc trưng từ tập dữ liệu
    X_train_opcode = np.array(df_train.iloc[:, 11:].values)
    X_test_opcode = np.array(df_test.iloc[:, 11:].values)

    # Lấy nhãn từ tập dữ liệu
    y_train = df_train[selected_labels].values
    y_test = df_test[selected_labels].values
    labels = data[selected_labels].values

    print(f"Load Data for {label_count}-Label MultiLabel success!!")
    return X_train_opcode, X_test_opcode, X_train_source, X_test_source, y_train, y_test, labels

# %%
X_train_opcode_8, X_test_opcode_8, X_train_source_8, X_test_source_8, y_train_8, y_test_8, labels_dataset_8 = load_dataset(8)
# Out:
# Load Features codeBERT success!!
# Load Data for 8-Label MultiLabel success!!

# %%
# Load GNN
import torch
import pickle
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
import numpy as np

# Load data
input_file = 'DATASET/gnn_input_binary_labels.pkl'

with open(input_file, 'rb') as f:
    data = pickle.load(f)

loaded_feature_matrices = data['features']
adj_matrices = data['adj_matrices']
# loaded_all_labels = data['labels']
# Define the target dimension
target_dim = 6000

def pad_or_truncate_features(features, target_dim):
    if features.shape[1] > target_dim:
        return features[:, :target_dim]
    elif features.shape[1] < target_dim:
        padded_features = np.zeros((features.shape[0], target_dim))
        padded_features[:, :features.shape[1]] = features
        return padded_features
    else:
        return features

# Function to create PyTorch Geometric Data object from feature matrices and labels
def create_pyg_data(features, adj_matrix, labels, target_dim):
    num_nodes = features.shape[0]
    edge_index = torch.tensor(np.array(adj_matrix), dtype=torch.long).nonzero(as_tuple=False).t().contiguous()
    x = torch.tensor(pad_or_truncate_features(features, target_dim), dtype=torch.float)
    y = torch.tensor(labels, dtype=torch.float)  # Ensure labels are float for BCEWithLogitsLoss
    data = Data(x=x, edge_index=edge_index, y=y)
    return data

data_list = [create_pyg_data(features, adj_matrix, labels, target_dim) for features, adj_matrix, labels in zip(loaded_feature_matrices, adj_matrices, labels_dataset_8)]

# Create DataLoader
train_loader = DataLoader(data_list[:int(len(data_list)*0.8)], batch_size=32, shuffle=True)  # Adjust batch size as needed
test_loader = DataLoader(data_list[int(len(data_list)*0.8):], batch_size=32, shuffle=False)  # Adjust batch size as needed

# %%
from torch_geometric.nn import GATConv
class GAT(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, heads=8):
        super(GAT, self).__init__()
        self.conv1 = GATConv(in_channels, hidden_channels, heads=heads, dropout=0.3)
        self.bn1 = BatchNorm1d(hidden_channels * heads)
        self.conv2 = GATConv(hidden_channels * heads, hidden_channels, heads=1, concat=False, dropout=0.3)
        self.bn2 = BatchNorm1d(hidden_channels)
        self.lin = Linear(hidden_channels, out_channels)

    def forward(self, data):
        x, edge_index, batch = data.x, data.edge_index, data.batch
        x = self.conv1(x, edge_index)
        x = self.bn1(x)
        x = x.relu()
        x = self.conv2(x, edge_index)
        x = self.bn2(x)
        x = x.relu()

        x = global_mean_pool(x, batch)  # Pooling layer

        # x = F.dropout(x, p=0.3, training=self.training)
        # x = self.lin(x)
        # x = torch.sigmoid(x)  # Sigmoid activation for multi-label classification

        return x

# Load mô hình GNN
model_path = 'Unimodal/GAT_30E.pth'

# Adjust the in_channels, hidden_channels, and out_channels parameters based on the training settings
gnn_model = GAT(in_channels=6000, hidden_channels=64, out_channels=8)
gnn_model.load_state_dict(torch.load(model_path))
gnn_model.eval()  # Set the model to evaluation mode

# Function to get GNN outputs for a given DataLoader
def get_gnn_outputs(loader):
    outputs = []
    with torch.no_grad():
        for data in loader:
            out = gnn_model(data)
            outputs.append(out.numpy())
    return np.concatenate(outputs)

# Get GNN outputs for training and testing data
gnn_train_outputs = get_gnn_outputs(train_loader)
gnn_test_outputs = get_gnn_outputs(test_loader)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_19884\526977021.py:33: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   gnn_model.load_state_dict(torch.load(model_path))

# %%
bert_model = load_model("Unimodal/CodeBERT_30E.h5", compile=False)
lstm_model = load_model("Unimodal/BiLSTM_Full_2gram_Softmax_30E.h5", compile=False)

# %%
for i, layer in enumerate(bert_model.layers):
    print(i, layer.name, layer.output_shape)
print()
for i, layer in enumerate(lstm_model.layers):
    print(i, layer.name, layer.output_shape)
# Out:
# 0 sourcecode_features [(None, 768)]
# 1 codebert_dense_layer_1 (None, 512)
# 2 codebert_bn_1 (None, 512)
# 3 codebert_dropout_layer_1 (None, 512)
# 4 codebert_dense_layer_2 (None, 256)
# 5 codebert_bn_2 (None, 256)
# 6 codebert_dropout_layer_2 (None, 256)
# 7 codebert_dense_layer_out (None, 128)
# 8 codebert_bn (None, 128)
# 9 codebert_output (None, 8)
#
# 0 input_1 [(None, 280)]
# 1 embedding (None, 280, 286)
# 2 bidirectional (None, 256)
# 3 dropout (None, 256)
# 4 batch_normalization1 (None, 256)
# 5 drop_out (None, 256)
# 6 dense (None, 128)
# 7 batch_normalization (None, 128)
# 8 dropout_1 (None, 128)
# 9 dense_1 (None, 128)
# 10 dense_2 (None, 8)

# %%
embedding_bert = Model(
    inputs=bert_model.input,
    outputs=bert_model.get_layer("sourcecode_features").output
)

embedding_lstm = Model(
    inputs=lstm_model.input,
    outputs=lstm_model.get_layer("bidirectional").output
)

# %%
lstm_train = embedding_lstm.predict(X_train_opcode_8)
lstm_test = embedding_lstm.predict(X_test_opcode_8)
codebert_train = embedding_bert.predict(X_train_source_8)
codebert_test = embedding_bert.predict(X_test_source_8)
# Out:
# 992/992 [==============================] - 98s 98ms/step
# 248/248 [==============================] - 22s 87ms/step
# 992/992 [==============================] - 1s 558us/step
# 248/248 [==============================] - 0s 541us/step

# %%
codebert_input = Input(shape=(768,), name="codebert_input")
lstm_input = Input(shape=(256,), name="lstm_input")
gnn_input = Input(shape=(64,), name="gnn_input")

proj_dim = 128

codebert_proj = Dense(proj_dim, activation="relu")(codebert_input)
lstm_proj = Dense(proj_dim, activation="relu")(lstm_input)
gnn_proj = Dense(proj_dim, activation="relu")(gnn_input)

# %%
codebert_token = Reshape((1, proj_dim))(codebert_proj)
lstm_token = Reshape((1, proj_dim))(lstm_proj)
gnn_token = Reshape((1, proj_dim))(gnn_proj)

# %%
def cross_attn_block(q, kv, name):

    attn = MultiHeadAttention(
        num_heads=4,
        key_dim=32,
        name=name
    )(q, kv)

    out = LayerNormalization(name=f"{name}_ln")(q + attn)

    return out

def self_attn_block(x, name):

    attn = MultiHeadAttention(
        num_heads=4,
        key_dim=32,
        name=f"{name}_self_attn"
    )(x, x)

    x = LayerNormalization(name=f"{name}_ln")(x + attn)

    return x

# %%
codebert_sa = self_attn_block(codebert_token, "codebert")
lstm_sa = self_attn_block(lstm_token, "lstm")
gnn_sa = self_attn_block(gnn_token, "gnn")
codebert_sa = self_attn_block(codebert_token, "codebert2")
lstm_sa = self_attn_block(lstm_token, "lstm2")
gnn_sa = self_attn_block(gnn_token, "gnn2")

cb_lstm = cross_attn_block(codebert_sa, lstm_sa, "cb_lstm")
lstm_cb = cross_attn_block(lstm_sa, codebert_sa, "lstm_cb")

cb_gnn = cross_attn_block(codebert_sa, gnn_sa, "cb_gnn")
gnn_cb = cross_attn_block(gnn_sa, codebert_sa, "gnn_cb")

lstm_gnn = cross_attn_block(lstm_sa, gnn_sa, "lstm_gnn")
gnn_lstm = cross_attn_block(gnn_sa, lstm_sa, "gnn_lstm")

# %%
fusion = Concatenate(axis=1)([
    cb_lstm,
    lstm_cb,
    cb_gnn,
    gnn_cb,
    lstm_gnn,
    gnn_lstm
])

fusion = Flatten()(fusion)

# %%
x = Dense(256, activation="relu")(fusion)
x = Dropout(0.3)(x)

x = Dense(128, activation="relu")(x)

output = Dense(8, activation="sigmoid")(x)

fusion_model = Model(
    inputs=[codebert_input, lstm_input, gnn_input],
    outputs=output
)

fusion_model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=[tf.keras.metrics.BinaryAccuracy(name='accuracy')]
)

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='loss', patience=5, restore_best_weights=True)

# %%
fusion_model.fit(
    [codebert_train, lstm_train, gnn_train_outputs],
    y_train_8,
    validation_data=([codebert_test, lstm_test, gnn_test_outputs], y_test_8),
    epochs= 30,
    batch_size=32,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/30
# 992/992 [==============================] - 11s 8ms/step - loss: 0.2543 - accuracy: 0.3443 - val_loss: 0.1928 - val_accuracy: 0.3704
# Epoch 2/30
# 992/992 [==============================] - 7s 7ms/step - loss: 0.2251 - accuracy: 0.3331 - val_loss: 0.1847 - val_accuracy: 0.4128
# Epoch 3/30
# 992/992 [==============================] - 7s 7ms/step - loss: 0.2148 - accuracy: 0.3340 - val_loss: 0.1797 - val_accuracy: 0.4582
# Epoch 4/30
# 992/992 [==============================] - 7s 7ms/step - loss: 0.2079 - accuracy: 0.3445 - val_loss: 0.1634 - val_accuracy: 0.3535
# Epoch 5/30
# 992/992 [==============================] - 7s 8ms/step - loss: 0.2025 - accuracy: 0.3350 - val_loss: 0.1560 - val_accuracy: 0.4095
# Epoch 6/30
# 992/992 [==============================] - 7s 8ms/step - loss: 0.1965 - accuracy: 0.3360 - val_loss: 0.1565 - val_accuracy: 0.4828
# Epoch 7/30
# 992/992 [==============================] - 7s 8ms/step - loss: 0.1917 - accuracy: 0.3451 - val_loss: 0.1606 - val_accuracy: 0.5109
# Epoch 8/30
# 992/992 [==============================] - 7s 7ms/step - loss: 0.1869 - accuracy: 0.3431 - val_loss: 0.1609 - val_accuracy: 0.4806
# Epoch 9/30
# 992/992 [==============================] - 7s 8ms/step - loss: 0.1826 - accuracy: 0.3356 - val_loss: 0.1591 - val_accuracy: 0.3736
# Epoch 10/30
# 992/992 [==============================] - 8s 8ms/step - loss: 0.1780 - accuracy: 0.3436 - val_loss: 0.1618 - val_accuracy: 0.3802
# Epoch 11/30
# 992/992 [==============================] - 9s 9ms/step - loss: 0.1736 - accuracy: 0.3482 - val_loss: 0.1566 - val_accuracy: 0.4472
# Epoch 12/30
# 992/992 [==============================] - 8s 8ms/step - loss: 0.1692 - accuracy: 0.3484 - val_loss: 0.1589 - val_accuracy: 0.4082
# Epoch 13/30
# 992/992 [==============================] - 8s 8ms/step - loss: 0.1656 - accuracy: 0.3413 - val_loss: 0.1630 - val_accuracy: 0.4426
# Epoch 14/30
# 992/992 [==============================] - 8s 8ms/step - loss: 0.1626 - accuracy: 0.3475 - val_loss: 0.1711 - val_accuracy: 0.4774
# Epoch 15/30
# 992/992 [==============================] - 8s 8ms/step - loss: 0.1585 - accuracy: 0.3512 - val_loss: 0.1663 - val_accuracy: 0.3635
# Epoch 16/30
# 992/992 [==============================] - 8s 8ms/step - loss: 0.1550 - accuracy: 0.3501 - val_loss: 0.1644 - val_accuracy: 0.4183
# Epoch 17/30
# 992/992 [==============================] - 8s 8ms/step - loss: 0.1515 - accuracy: 0.3503 - val_loss: 0.1705 - val_accuracy: 0.3523
# Epoch 18/30
# 992/992 [==============================] - 8s 8ms/step - loss: 0.1479 - accuracy: 0.3421 - val_loss: 0.1738 - val_accuracy: 0.4254
# Epoch 19/30
# 992/992 [==============================] - 8s 8ms/step - loss: 0.1457 - accuracy: 0.3424 - val_loss: 0.1705 - val_accuracy: 0.3770
# Epoch 20/30
# 992/992 [==============================] - 8s 8ms/step - loss: 0.1426 - accuracy: 0.3472 - val_loss: 0.1785 - val_accuracy: 0.4042
# Epoch 21/30
# 992/992 [==============================] - 8s 8ms/step - loss: 0.1406 - accuracy: 0.3482 - val_loss: 0.1765 - val_accuracy: 0.4075
# Epoch 22/30
# 992/992 [==============================] - 8s 8ms/step - loss: 0.1385 - accuracy: 0.3574 - val_loss: 0.1787 - val_accuracy: 0.3939
# Epoch 23/30
# 992/992 [==============================] - 8s 8ms/step - loss: 0.1352 - accuracy: 0.3553 - val_loss: 0.1819 - val_accuracy: 0.4336
# Epoch 24/30
# 992/992 [==============================] - 8s 8ms/step - loss: 0.1317 - accuracy: 0.3658 - val_loss: 0.1813 - val_accuracy: 0.4293
# Epoch 25/30
# 992/992 [==============================] - 8s 8ms/step - loss: 0.1300 - accuracy: 0.3654 - val_loss: 0.1784 - val_accuracy: 0.4048
# Epoch 26/30
# 992/992 [==============================] - 8s 8ms/step - loss: 0.1287 - accuracy: 0.3615 - val_loss: 0.1806 - val_accuracy: 0.4120
# Epoch 27/30
# 992/992 [==============================] - 8s 8ms/step - loss: 0.1268 - accuracy: 0.3644 - val_loss: 0.1861 - val_accuracy: 0.4328
# Epoch 28/30
# 992/992 [==============================] - 8s 8ms/step - loss: 0.1248 - accuracy: 0.3562 - val_loss: 0.1888 - val_accuracy: 0.3955
# Epoch 29/30
# 992/992 [==============================] - 8s 8ms/step - loss: 0.1233 - accuracy: 0.3715 - val_loss: 0.1855 - val_accuracy: 0.4018
# Epoch 30/30
# 992/992 [==============================] - 8s 8ms/step - loss: 0.1211 - accuracy: 0.3652 - val_loss: 0.1960 - val_accuracy: 0.4017

# %%
def apply_threshold(y_pred_prob, threshold=0.5):
    y_pred_prob = np.array(y_pred_prob)
    y_pred_thresh = np.zeros_like(y_pred_prob)
    y_pred_thresh[y_pred_prob >= threshold] = 1
    return y_pred_thresh
y_pred_prob = fusion_model.predict([codebert_test, lstm_test, gnn_test_outputs])
y_pred = apply_threshold(y_pred_prob, threshold=0.5)
# Out:
# 248/248 [==============================] - 1s 3ms/step

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, confusion_matrix
label_names = ['Other', 'access_control', 'arithmetic', 'denial_service',
                     'front_running', 'reentrancy', 'time_manipulation',
                     'unchecked_low_calls']

for i, label in enumerate(label_names[:8]):
    precision = precision_score(y_test_8[:, i], y_pred[:, i])
    recall = recall_score(y_test_8[:, i], y_pred[:, i])
    f1 = f1_score(y_test_8[:, i], y_pred[:, i])
    accuracy = accuracy_score(y_test_8[:, i], y_pred[:, i])
    # Tính confusion matrix cho nhãn i
    tn, fp, fn, tp = confusion_matrix(y_test_8[:, i], y_pred[:, i]).ravel()

    # Tính FPR và FNR
    fpr = fp / (fp + tn)
    fnr = fn / (fn + tp)

    print(f"Metrics for {label}:")
    print(f"  Accuracy:  {accuracy:.4f}")
    print(f"  Precision: {precision:.4f}")
    print(f"  Recall:    {recall:.4f}")
    print(f"  F1-Score:  {f1:.4f}")
    #print(f"  FPR:       {fpr:.4f}")
    #print(f"  FNR:       {fnr:.4f}")
    print()
# Out:
# Metrics for Other:
#   Accuracy:  0.8740
#   Precision: 0.8794
#   Recall:    0.9007
#   F1-Score:  0.8899
#
# Metrics for access_control:
#   Accuracy:  0.9527
#   Precision: 0.7395
#   Recall:    0.6811
#   F1-Score:  0.7091
#
# Metrics for arithmetic:
#   Accuracy:  0.9445
#   Precision: 0.9500
#   Recall:    0.9786
#   F1-Score:  0.9641
#
# Metrics for denial_service:
#   Accuracy:  0.9622
#   Precision: 0.9011
#   Recall:    0.8775
#   F1-Score:  0.8891
#
# Metrics for front_running:
#   Accuracy:  0.9493
#   Precision: 0.8495
#   Recall:    0.7988
#   F1-Score:  0.8234
#
# Metrics for reentrancy:
#   Accuracy:  0.9082
#   Precision: 0.8841
#   Recall:    0.8035
#   F1-Score:  0.8419
#
# Metrics for time_manipulation:
#   Accuracy:  0.9583
#   Precision: 0.6983
#   Recall:    0.6378
#   F1-Score:  0.6667
#
# Metrics for unchecked_low_calls:
#   Accuracy:  0.9298
#   Precision: 0.8955
#   Recall:    0.8778
#   F1-Score:  0.8865

# %% [markdown]
# # Mô hình khởi tạo

# %% [markdown]
# # Model mở rộng

# %%
def extend_model(initial_model, total_label_count):
    # Freeze all layers in the initial model
    for layer in initial_model.layers:
        layer.trainable = False

    # Get the output of the second last layer of the initial model
    dense_features = initial_model.get_layer('drop_multilabel').output

    # Reshape the output to match the expected input shape of the new layer
    dense_features = Reshape((128,), name ='reshape_extend')(dense_features)

    # Create new output layer for the additional labels
    output_extended_labels = Dense(total_label_count, activation='sigmoid', name='output_extended_labels')(dense_features)

    # Create extended model
    model_extended = tf.keras.models.Model(inputs=initial_model.inputs, outputs=output_extended_labels)

    # Compile the extended model
    METRICS = [
        tf.keras.metrics.BinaryAccuracy(name='accuracy'),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]

    model_extended.compile(optimizer='adam', loss='binary_crossentropy', metrics=METRICS)

    return model_extended

# %%
total_label_count = 5
extended_model = extend_model(model_initial, total_label_count)
extended_model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 total_label_count = 5
# ----> 2 extended_model = extend_model(model_initial, total_label_count)
#       3 extended_model.summary()
#
# NameError: name 'model_initial' is not defined

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='accuracy', patience=5, restore_best_weights=True)

# %%
extended_model.fit([X_train_source_5, X_train_opcode_5, gnn_train_outputs], y_train_5, epochs=1, batch_size=32, callbacks=[early_stopping])
# Out:
# 992/992 [==============================] - 82s 79ms/step - loss: 0.3072 - accuracy: 0.8722 - precision: 0.8632 - recall: 0.8103

# %% [markdown]
# # END

# %% [markdown]
# # 5 đến 8

# %%
X_train_opcode_5, X_test_opcode_5, X_train_source_5, X_test_source_5, y_train_5, y_test_5, labels_dataset_5 = load_dataset(5)
# Out:
# Load Features codeBERT success!!
# Load Data for 5-Label MultiLabel success!!

# %%
initial_label_count = 5
model_initial = create_model_with_labels(initial_label_count, total_label_count=8)
model_initial.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 280)]                0         []
#
#  sourcecode_features (Input  [(None, 768)]                0         []
#  Layer)
#
#  embedding (Embedding)       (None, 280, 286)             9724000   ['input_1[0][0]']
#
#  codebert_dense_layer_1 (De  (None, 512)                  393728    ['sourcecode_features[0][0]']
#  nse)
#
#  bidirectional (Bidirection  (None, 256)                  424960    ['embedding[0][0]']
#  al)
#
#  codebert_bn_1 (BatchNormal  (None, 512)                  2048      ['codebert_dense_layer_1[0][0]
#  ization)                                                           ']
#
#  dropout (Dropout)           (None, 256)                  0         ['bidirectional[0][0]']
#
#  codebert_dropout_layer_1 (  (None, 512)                  0         ['codebert_bn_1[0][0]']
#  Dropout)
#
#  batch_normalization1 (Batc  (None, 256)                  1024      ['dropout[0][0]']
#  hNormalization)
#
#  codebert_dense_layer_2 (De  (None, 256)                  131328    ['codebert_dropout_layer_1[0][
#  nse)                                                               0]']
#
#  drop_out (Dropout)          (None, 256)                  0         ['batch_normalization1[0][0]']
#
#  codebert_bn_2 (BatchNormal  (None, 256)                  1024      ['codebert_dense_layer_2[0][0]
#  ization)                                                           ']
#
#  dense (Dense)               (None, 128)                  32896     ['drop_out[0][0]']
#
#  codebert_dropout_layer_2 (  (None, 256)                  0         ['codebert_bn_2[0][0]']
#  Dropout)
#
#  batch_normalization (Batch  (None, 128)                  512       ['dense[0][0]']
#  Normalization)
#
#  codebert_dense_layer_out (  (None, 128)                  32896     ['codebert_dropout_layer_2[0][
#  Dense)                                                             0]']
#
#  dropout_1 (Dropout)         (None, 128)                  0         ['batch_normalization[0][0]']
#
#  codebert_bn (BatchNormaliz  (None, 128)                  512       ['codebert_dense_layer_out[0][
#  ation)                                                             0]']
#
#  dense_1 (Dense)             (None, 128)                  16512     ['dropout_1[0][0]']
#
#  codebert_output (Dense)     (None, 8)                    1032      ['codebert_bn[0][0]']
#
#  dense_2 (Dense)             (None, 8)                    1032      ['dense_1[0][0]']
#
#  gnn_output (InputLayer)     [(None, 8)]                  0         []
#
#  concatenate_1 (Concatenate  (None, 24)                   0         ['codebert_output[0][0]',
#  )                                                                   'dense_2[0][0]',
#                                                                      'gnn_output[0][0]']
#
#  reshape_1 (Reshape)         (None, 24, 1)                0         ['concatenate_1[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 22, 64)               256       ['reshape_1[0][0]']
#
#  flatten_1 (Flatten)         (None, 1408)                 0         ['conv1d_1[0][0]']
#
#  dense_multilabel (Dense)    (None, 128)                  180352    ['flatten_1[0][0]']
#
#  drop_multilabel (Dropout)   (None, 128)                  0         ['dense_multilabel[0][0]']
#
#  output_initial_labels (Den  (None, 5)                    645       ['drop_multilabel[0][0]']
#  se)
#
# ==================================================================================================
# Total params: 10944757 (41.75 MB)
# Trainable params: 181253 (708.02 KB)
# Non-trainable params: 10763504 (41.06 MB)
# __________________________________________________________________________________________________

# %%
model_initial.fit([X_train_source_5, X_train_opcode_5, gnn_train_outputs], y_train_5, epochs=30, batch_size=32, validation_data=([X_test_source_5, X_test_opcode_5, gnn_test_outputs], y_test_5))
# Out:
# Epoch 1/30
# 992/992 [==============================] - 123s 120ms/step - loss: 0.2622 - accuracy: 0.8964 - precision: 0.8766 - recall: 0.8639 - val_loss: 0.1657 - val_accuracy: 0.9411 - val_precision: 0.9190 - val_recall: 0.9101
# Epoch 2/30
# 992/992 [==============================] - 120s 121ms/step - loss: 0.2389 - accuracy: 0.9055 - precision: 0.8849 - recall: 0.8793 - val_loss: 0.1591 - val_accuracy: 0.9413 - val_precision: 0.9293 - val_recall: 0.8988
# Epoch 3/30
# 992/992 [==============================] - 129s 130ms/step - loss: 0.2380 - accuracy: 0.9050 - precision: 0.8863 - recall: 0.8762 - val_loss: 0.1594 - val_accuracy: 0.9410 - val_precision: 0.9262 - val_recall: 0.9016
# Epoch 4/30
# 992/992 [==============================] - 124s 125ms/step - loss: 0.2371 - accuracy: 0.9058 - precision: 0.8875 - recall: 0.8768 - val_loss: 0.1553 - val_accuracy: 0.9418 - val_precision: 0.9253 - val_recall: 0.9049
# Epoch 5/30
# 992/992 [==============================] - 116s 117ms/step - loss: 0.2352 - accuracy: 0.9055 - precision: 0.8881 - recall: 0.8751 - val_loss: 0.1525 - val_accuracy: 0.9423 - val_precision: 0.9228 - val_recall: 0.9095
# Epoch 6/30
# 992/992 [==============================] - 121s 122ms/step - loss: 0.2336 - accuracy: 0.9058 - precision: 0.8900 - recall: 0.8735 - val_loss: 0.1540 - val_accuracy: 0.9417 - val_precision: 0.9249 - val_recall: 0.9051
# Epoch 7/30
# 992/992 [==============================] - 135s 136ms/step - loss: 0.2339 - accuracy: 0.9059 - precision: 0.8893 - recall: 0.8749 - val_loss: 0.1510 - val_accuracy: 0.9410 - val_precision: 0.9297 - val_recall: 0.8976
# Epoch 8/30
# 992/992 [==============================] - 123s 124ms/step - loss: 0.2323 - accuracy: 0.9060 - precision: 0.8893 - recall: 0.8750 - val_loss: 0.1505 - val_accuracy: 0.9420 - val_precision: 0.9212 - val_recall: 0.9103
# Epoch 9/30
# 992/992 [==============================] - 119s 120ms/step - loss: 0.2317 - accuracy: 0.9068 - precision: 0.8902 - recall: 0.8763 - val_loss: 0.1479 - val_accuracy: 0.9419 - val_precision: 0.9302 - val_recall: 0.8998
# Epoch 10/30
# 992/992 [==============================] - 117s 118ms/step - loss: 0.2309 - accuracy: 0.9065 - precision: 0.8906 - recall: 0.8748 - val_loss: 0.1479 - val_accuracy: 0.9415 - val_precision: 0.9250 - val_recall: 0.9042
# Epoch 11/30
# 992/992 [==============================] - 124s 125ms/step - loss: 0.2315 - accuracy: 0.9065 - precision: 0.8902 - recall: 0.8752 - val_loss: 0.1488 - val_accuracy: 0.9416 - val_precision: 0.9283 - val_recall: 0.9010
# Epoch 12/30
# 992/992 [==============================] - 128s 129ms/step - loss: 0.2315 - accuracy: 0.9062 - precision: 0.8903 - recall: 0.8743 - val_loss: 0.1481 - val_accuracy: 0.9417 - val_precision: 0.9250 - val_recall: 0.9050
# Epoch 13/30
# 992/992 [==============================] - 119s 120ms/step - loss: 0.2304 - accuracy: 0.9063 - precision: 0.8898 - recall: 0.8752 - val_loss: 0.1522 - val_accuracy: 0.9414 - val_precision: 0.9258 - val_recall: 0.9031
# Epoch 14/30
# 992/992 [==============================] - 128s 129ms/step - loss: 0.2294 - accuracy: 0.9069 - precision: 0.8908 - recall: 0.8756 - val_loss: 0.1479 - val_accuracy: 0.9417 - val_precision: 0.9214 - val_recall: 0.9093
# Epoch 15/30
# 992/992 [==============================] - 145s 146ms/step - loss: 0.2302 - accuracy: 0.9069 - precision: 0.8913 - recall: 0.8749 - val_loss: 0.1477 - val_accuracy: 0.9423 - val_precision: 0.9238 - val_recall: 0.9082
# Epoch 16/30
# 992/992 [==============================] - 138s 139ms/step - loss: 0.2305 - accuracy: 0.9063 - precision: 0.8901 - recall: 0.8749 - val_loss: 0.1490 - val_accuracy: 0.9419 - val_precision: 0.9234 - val_recall: 0.9074
# Epoch 17/30
# 992/992 [==============================] - 139s 140ms/step - loss: 0.2297 - accuracy: 0.9066 - precision: 0.8914 - recall: 0.8741 - val_loss: 0.1470 - val_accuracy: 0.9421 - val_precision: 0.9234 - val_recall: 0.9082
# Epoch 18/30
# 992/992 [==============================] - 137s 138ms/step - loss: 0.2287 - accuracy: 0.9076 - precision: 0.8929 - recall: 0.8751 - val_loss: 0.1518 - val_accuracy: 0.9418 - val_precision: 0.9265 - val_recall: 0.9036
# Epoch 19/30
# 992/992 [==============================] - 139s 140ms/step - loss: 0.2301 - accuracy: 0.9064 - precision: 0.8920 - recall: 0.8728 - val_loss: 0.1465 - val_accuracy: 0.9420 - val_precision: 0.9285 - val_recall: 0.9021
# Epoch 20/30
# 992/992 [==============================] - 140s 141ms/step - loss: 0.2294 - accuracy: 0.9069 - precision: 0.8908 - recall: 0.8757 - val_loss: 0.1470 - val_accuracy: 0.9422 - val_precision: 0.9268 - val_recall: 0.9046
# Epoch 21/30
# 992/992 [==============================] - 141s 142ms/step - loss: 0.2296 - accuracy: 0.9071 - precision: 0.8914 - recall: 0.8754 - val_loss: 0.1481 - val_accuracy: 0.9422 - val_precision: 0.9213 - val_recall: 0.9110
# Epoch 22/30
# 992/992 [==============================] - 141s 142ms/step - loss: 0.2290 - accuracy: 0.9069 - precision: 0.8903 - recall: 0.8763 - val_loss: 0.1471 - val_accuracy: 0.9425 - val_precision: 0.9241 - val_recall: 0.9086
# Epoch 23/30
# 992/992 [==============================] - 141s 143ms/step - loss: 0.2290 - accuracy: 0.9073 - precision: 0.8905 - recall: 0.8773 - val_loss: 0.1470 - val_accuracy: 0.9421 - val_precision: 0.9256 - val_recall: 0.9055
# Epoch 24/30
# 992/992 [==============================] - 140s 142ms/step - loss: 0.2280 - accuracy: 0.9078 - precision: 0.8920 - recall: 0.8768 - val_loss: 0.1471 - val_accuracy: 0.9421 - val_precision: 0.9293 - val_recall: 0.9015
# Epoch 25/30
# 992/992 [==============================] - 142s 143ms/step - loss: 0.2280 - accuracy: 0.9071 - precision: 0.8922 - recall: 0.8745 - val_loss: 0.1486 - val_accuracy: 0.9424 - val_precision: 0.9165 - val_recall: 0.9171
# Epoch 26/30
# 992/992 [==============================] - 140s 141ms/step - loss: 0.2285 - accuracy: 0.9065 - precision: 0.8912 - recall: 0.8742 - val_loss: 0.1489 - val_accuracy: 0.9423 - val_precision: 0.9304 - val_recall: 0.9008
# Epoch 27/30
# 992/992 [==============================] - 143s 144ms/step - loss: 0.2275 - accuracy: 0.9077 - precision: 0.8920 - recall: 0.8765 - val_loss: 0.1468 - val_accuracy: 0.9421 - val_precision: 0.9245 - val_recall: 0.9070
# Epoch 28/30
# 992/992 [==============================] - 142s 143ms/step - loss: 0.2280 - accuracy: 0.9075 - precision: 0.8918 - recall: 0.8761 - val_loss: 0.1462 - val_accuracy: 0.9424 - val_precision: 0.9268 - val_recall: 0.9051
# Epoch 29/30
# 992/992 [==============================] - 151s 152ms/step - loss: 0.2278 - accuracy: 0.9073 - precision: 0.8914 - recall: 0.8760 - val_loss: 0.1471 - val_accuracy: 0.9425 - val_precision: 0.9252 - val_recall: 0.9074
# Epoch 30/30
# 992/992 [==============================] - 144s 145ms/step - loss: 0.2274 - accuracy: 0.9071 - precision: 0.8914 - recall: 0.8755 - val_loss: 0.1466 - val_accuracy: 0.9420 - val_precision: 0.9283 - val_recall: 0.9020

# %%
total_label_count = 8
extended_model = extend_model(model_initial, 5, total_label_count)
extended_model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 280)]                0         []
#
#  sourcecode_features (Input  [(None, 768)]                0         []
#  Layer)
#
#  embedding (Embedding)       (None, 280, 286)             9724000   ['input_1[0][0]']
#
#  codebert_dense_layer_1 (De  (None, 512)                  393728    ['sourcecode_features[0][0]']
#  nse)
#
#  bidirectional (Bidirection  (None, 256)                  424960    ['embedding[0][0]']
#  al)
#
#  codebert_bn_1 (BatchNormal  (None, 512)                  2048      ['codebert_dense_layer_1[0][0]
#  ization)                                                           ']
#
#  dropout (Dropout)           (None, 256)                  0         ['bidirectional[0][0]']
#
#  codebert_dropout_layer_1 (  (None, 512)                  0         ['codebert_bn_1[0][0]']
#  Dropout)
#
#  batch_normalization1 (Batc  (None, 256)                  1024      ['dropout[0][0]']
#  hNormalization)
#
#  codebert_dense_layer_2 (De  (None, 256)                  131328    ['codebert_dropout_layer_1[0][
#  nse)                                                               0]']
#
#  drop_out (Dropout)          (None, 256)                  0         ['batch_normalization1[0][0]']
#
#  codebert_bn_2 (BatchNormal  (None, 256)                  1024      ['codebert_dense_layer_2[0][0]
#  ization)                                                           ']
#
#  dense (Dense)               (None, 128)                  32896     ['drop_out[0][0]']
#
#  codebert_dropout_layer_2 (  (None, 256)                  0         ['codebert_bn_2[0][0]']
#  Dropout)
#
#  batch_normalization (Batch  (None, 128)                  512       ['dense[0][0]']
#  Normalization)
#
#  codebert_dense_layer_out (  (None, 128)                  32896     ['codebert_dropout_layer_2[0][
#  Dense)                                                             0]']
#
#  dropout_1 (Dropout)         (None, 128)                  0         ['batch_normalization[0][0]']
#
#  codebert_bn (BatchNormaliz  (None, 128)                  512       ['codebert_dense_layer_out[0][
#  ation)                                                             0]']
#
#  dense_1 (Dense)             (None, 128)                  16512     ['dropout_1[0][0]']
#
#  codebert_output (Dense)     (None, 8)                    1032      ['codebert_bn[0][0]']
#
#  dense_2 (Dense)             (None, 8)                    1032      ['dense_1[0][0]']
#
#  gnn_output (InputLayer)     [(None, 8)]                  0         []
#
#  concatenate_1 (Concatenate  (None, 24)                   0         ['codebert_output[0][0]',
#  )                                                                   'dense_2[0][0]',
#                                                                      'gnn_output[0][0]']
#
#  reshape_1 (Reshape)         (None, 24, 1)                0         ['concatenate_1[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 22, 64)               256       ['reshape_1[0][0]']
#
#  flatten_1 (Flatten)         (None, 1408)                 0         ['conv1d_1[0][0]']
#
#  dense_multilabel (Dense)    (None, 128)                  180352    ['flatten_1[0][0]']
#
#  drop_multilabel (Dropout)   (None, 128)                  0         ['dense_multilabel[0][0]']
#
#  reshape_extend (Reshape)    (None, 128)                  0         ['drop_multilabel[0][0]']
#
#  output_extended_labels (De  (None, 8)                    1032      ['reshape_extend[0][0]']
#  nse)
#
# ==================================================================================================
# Total params: 10945144 (41.75 MB)
# Trainable params: 1032 (4.03 KB)
# Non-trainable params: 10944112 (41.75 MB)
# __________________________________________________________________________________________________

# %%
extended_model.fit([X_train_source_8, X_train_opcode_8, gnn_train_outputs], y_train_8, epochs=30, batch_size=32, callbacks=[early_stopping])
# Out:
# Epoch 1/30
# 992/992 [==============================] - 118s 116ms/step - loss: 0.3456 - accuracy: 0.8498 - precision: 0.8357 - recall: 0.6841
# Epoch 2/30
# 992/992 [==============================] - 113s 114ms/step - loss: 0.2852 - accuracy: 0.8788 - precision: 0.8686 - recall: 0.7500
# Epoch 3/30
# 992/992 [==============================] - 112s 113ms/step - loss: 0.2791 - accuracy: 0.8816 - precision: 0.8635 - recall: 0.7661
# Epoch 4/30
# 992/992 [==============================] - 111s 112ms/step - loss: 0.2762 - accuracy: 0.8827 - precision: 0.8611 - recall: 0.7731
# Epoch 5/30
# 992/992 [==============================] - 112s 113ms/step - loss: 0.2756 - accuracy: 0.8830 - precision: 0.8586 - recall: 0.7771
# Epoch 6/30
# 992/992 [==============================] - 110s 111ms/step - loss: 0.2754 - accuracy: 0.8835 - precision: 0.8583 - recall: 0.7792
# Epoch 7/30
# 992/992 [==============================] - 109s 110ms/step - loss: 0.2753 - accuracy: 0.8834 - precision: 0.8579 - recall: 0.7795
# Epoch 8/30
# 992/992 [==============================] - 109s 110ms/step - loss: 0.2736 - accuracy: 0.8842 - precision: 0.8582 - recall: 0.7818
# Epoch 9/30
# 992/992 [==============================] - 108s 109ms/step - loss: 0.2746 - accuracy: 0.8842 - precision: 0.8581 - recall: 0.7820
# Epoch 10/30
# 992/992 [==============================] - 108s 109ms/step - loss: 0.2743 - accuracy: 0.8837 - precision: 0.8572 - recall: 0.7815
# Epoch 11/30
# 992/992 [==============================] - 109s 110ms/step - loss: 0.2745 - accuracy: 0.8841 - precision: 0.8564 - recall: 0.7838
# Epoch 12/30
# 992/992 [==============================] - 114s 114ms/step - loss: 0.2736 - accuracy: 0.8849 - precision: 0.8587 - recall: 0.7839
# Epoch 13/30
# 992/992 [==============================] - 115s 116ms/step - loss: 0.2734 - accuracy: 0.8844 - precision: 0.8572 - recall: 0.7839
# Epoch 14/30
# 992/992 [==============================] - 115s 116ms/step - loss: 0.2739 - accuracy: 0.8841 - precision: 0.8569 - recall: 0.7833
# Epoch 15/30
# 992/992 [==============================] - 128s 129ms/step - loss: 0.2738 - accuracy: 0.8843 - precision: 0.8561 - recall: 0.7851
# Epoch 16/30
# 992/992 [==============================] - 129s 130ms/step - loss: 0.2729 - accuracy: 0.8848 - precision: 0.8573 - recall: 0.7852
# Epoch 17/30
# 992/992 [==============================] - 128s 129ms/step - loss: 0.2746 - accuracy: 0.8835 - precision: 0.8550 - recall: 0.7836

# %%
extended_model.save('KLTN_5to8.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # 6 to 8

# %%
X_train_opcode_6, X_test_opcode_6, X_train_source_6, X_test_source_6, y_train_6, y_test_6, labels_dataset_6 = load_dataset(6)
# Out:
# Load Features codeBERT success!!
# Load Data for 6-Label MultiLabel success!!

# %%
initial_label_count = 6
model_initial = create_model_with_labels(initial_label_count, total_label_count=8)
model_initial.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 280)]                0         []
#
#  sourcecode_features (Input  [(None, 768)]                0         []
#  Layer)
#
#  embedding (Embedding)       (None, 280, 286)             9724000   ['input_1[0][0]']
#
#  codebert_dense_layer_1 (De  (None, 512)                  393728    ['sourcecode_features[0][0]']
#  nse)
#
#  bidirectional (Bidirection  (None, 256)                  424960    ['embedding[0][0]']
#  al)
#
#  codebert_bn_1 (BatchNormal  (None, 512)                  2048      ['codebert_dense_layer_1[0][0]
#  ization)                                                           ']
#
#  dropout (Dropout)           (None, 256)                  0         ['bidirectional[0][0]']
#
#  codebert_dropout_layer_1 (  (None, 512)                  0         ['codebert_bn_1[0][0]']
#  Dropout)
#
#  batch_normalization1 (Batc  (None, 256)                  1024      ['dropout[0][0]']
#  hNormalization)
#
#  codebert_dense_layer_2 (De  (None, 256)                  131328    ['codebert_dropout_layer_1[0][
#  nse)                                                               0]']
#
#  drop_out (Dropout)          (None, 256)                  0         ['batch_normalization1[0][0]']
#
#  codebert_bn_2 (BatchNormal  (None, 256)                  1024      ['codebert_dense_layer_2[0][0]
#  ization)                                                           ']
#
#  dense (Dense)               (None, 128)                  32896     ['drop_out[0][0]']
#
#  codebert_dropout_layer_2 (  (None, 256)                  0         ['codebert_bn_2[0][0]']
#  Dropout)
#
#  batch_normalization (Batch  (None, 128)                  512       ['dense[0][0]']
#  Normalization)
#
#  codebert_dense_layer_out (  (None, 128)                  32896     ['codebert_dropout_layer_2[0][
#  Dense)                                                             0]']
#
#  dropout_1 (Dropout)         (None, 128)                  0         ['batch_normalization[0][0]']
#
#  codebert_bn (BatchNormaliz  (None, 128)                  512       ['codebert_dense_layer_out[0][
#  ation)                                                             0]']
#
#  dense_1 (Dense)             (None, 128)                  16512     ['dropout_1[0][0]']
#
#  codebert_output (Dense)     (None, 8)                    1032      ['codebert_bn[0][0]']
#
#  dense_2 (Dense)             (None, 8)                    1032      ['dense_1[0][0]']
#
#  gnn_output (InputLayer)     [(None, 8)]                  0         []
#
#  concatenate_2 (Concatenate  (None, 24)                   0         ['codebert_output[0][0]',
#  )                                                                   'dense_2[0][0]',
#                                                                      'gnn_output[0][0]']
#
#  reshape_2 (Reshape)         (None, 24, 1)                0         ['concatenate_2[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 22, 64)               256       ['reshape_2[0][0]']
#
#  flatten_2 (Flatten)         (None, 1408)                 0         ['conv1d_2[0][0]']
#
#  dense_multilabel (Dense)    (None, 128)                  180352    ['flatten_2[0][0]']
#
#  drop_multilabel (Dropout)   (None, 128)                  0         ['dense_multilabel[0][0]']
#
#  output_initial_labels (Den  (None, 6)                    774       ['drop_multilabel[0][0]']
#  se)
#
# ==================================================================================================
# Total params: 10944886 (41.75 MB)
# Trainable params: 181382 (708.52 KB)
# Non-trainable params: 10763504 (41.06 MB)
# __________________________________________________________________________________________________

# %%
model_initial.fit([X_train_source_6, X_train_opcode_6, gnn_train_outputs], y_train_6, epochs=30, batch_size=32, validation_data=([X_test_source_6, X_test_opcode_6, gnn_test_outputs], y_test_6))
# Out:
# Epoch 1/30
# 992/992 [==============================] - 172s 169ms/step - loss: 0.2744 - accuracy: 0.8922 - precision: 0.8674 - recall: 0.8478 - val_loss: 0.1835 - val_accuracy: 0.9352 - val_precision: 0.9047 - val_recall: 0.9044
# Epoch 2/30
# 992/992 [==============================] - 168s 169ms/step - loss: 0.2537 - accuracy: 0.8998 - precision: 0.8744 - recall: 0.8620 - val_loss: 0.1766 - val_accuracy: 0.9360 - val_precision: 0.9201 - val_recall: 0.8885
# Epoch 3/30
# 992/992 [==============================] - 162s 163ms/step - loss: 0.2518 - accuracy: 0.8997 - precision: 0.8747 - recall: 0.8612 - val_loss: 0.1696 - val_accuracy: 0.9367 - val_precision: 0.9153 - val_recall: 0.8965
# Epoch 4/30
# 992/992 [==============================] - 169s 170ms/step - loss: 0.2475 - accuracy: 0.9009 - precision: 0.8760 - recall: 0.8632 - val_loss: 0.1711 - val_accuracy: 0.9354 - val_precision: 0.9085 - val_recall: 0.9004
# Epoch 5/30
# 992/992 [==============================] - 160s 161ms/step - loss: 0.2485 - accuracy: 0.9009 - precision: 0.8775 - recall: 0.8611 - val_loss: 0.1678 - val_accuracy: 0.9366 - val_precision: 0.9176 - val_recall: 0.8934
# Epoch 6/30
# 992/992 [==============================] - 163s 165ms/step - loss: 0.2462 - accuracy: 0.9012 - precision: 0.8786 - recall: 0.8607 - val_loss: 0.1671 - val_accuracy: 0.9364 - val_precision: 0.9222 - val_recall: 0.8874
# Epoch 7/30
# 992/992 [==============================] - 164s 166ms/step - loss: 0.2464 - accuracy: 0.9007 - precision: 0.8790 - recall: 0.8585 - val_loss: 0.1671 - val_accuracy: 0.9359 - val_precision: 0.9137 - val_recall: 0.8957
# Epoch 8/30
# 992/992 [==============================] - 156s 157ms/step - loss: 0.2449 - accuracy: 0.9015 - precision: 0.8804 - recall: 0.8591 - val_loss: 0.1670 - val_accuracy: 0.9362 - val_precision: 0.9254 - val_recall: 0.8833
# Epoch 9/30
# 992/992 [==============================] - 150s 151ms/step - loss: 0.2458 - accuracy: 0.9007 - precision: 0.8811 - recall: 0.8558 - val_loss: 0.1644 - val_accuracy: 0.9372 - val_precision: 0.9209 - val_recall: 0.8915
# Epoch 10/30
# 992/992 [==============================] - 163s 164ms/step - loss: 0.2440 - accuracy: 0.9016 - precision: 0.8826 - recall: 0.8567 - val_loss: 0.1632 - val_accuracy: 0.9366 - val_precision: 0.9187 - val_recall: 0.8920
# Epoch 11/30
# 992/992 [==============================] - 161s 162ms/step - loss: 0.2442 - accuracy: 0.9012 - precision: 0.8831 - recall: 0.8548 - val_loss: 0.1649 - val_accuracy: 0.9366 - val_precision: 0.9272 - val_recall: 0.8825
# Epoch 12/30
# 992/992 [==============================] - 156s 157ms/step - loss: 0.2434 - accuracy: 0.9022 - precision: 0.8837 - recall: 0.8570 - val_loss: 0.1641 - val_accuracy: 0.9370 - val_precision: 0.9256 - val_recall: 0.8857
# Epoch 13/30
# 992/992 [==============================] - 152s 154ms/step - loss: 0.2431 - accuracy: 0.9013 - precision: 0.8829 - recall: 0.8554 - val_loss: 0.1620 - val_accuracy: 0.9368 - val_precision: 0.9224 - val_recall: 0.8885
# Epoch 14/30
# 992/992 [==============================] - 144s 145ms/step - loss: 0.2422 - accuracy: 0.9019 - precision: 0.8835 - recall: 0.8565 - val_loss: 0.1634 - val_accuracy: 0.9363 - val_precision: 0.9219 - val_recall: 0.8874
# Epoch 15/30
# 992/992 [==============================] - 147s 148ms/step - loss: 0.2420 - accuracy: 0.9021 - precision: 0.8845 - recall: 0.8557 - val_loss: 0.1625 - val_accuracy: 0.9367 - val_precision: 0.9220 - val_recall: 0.8886
# Epoch 16/30
# 992/992 [==============================] - 146s 147ms/step - loss: 0.2414 - accuracy: 0.9016 - precision: 0.8839 - recall: 0.8549 - val_loss: 0.1614 - val_accuracy: 0.9364 - val_precision: 0.9182 - val_recall: 0.8922
# Epoch 17/30
# 992/992 [==============================] - 139s 141ms/step - loss: 0.2406 - accuracy: 0.9025 - precision: 0.8844 - recall: 0.8573 - val_loss: 0.1641 - val_accuracy: 0.9361 - val_precision: 0.9204 - val_recall: 0.8885
# Epoch 18/30
# 992/992 [==============================] - 140s 141ms/step - loss: 0.2422 - accuracy: 0.9012 - precision: 0.8829 - recall: 0.8550 - val_loss: 0.1621 - val_accuracy: 0.9369 - val_precision: 0.9188 - val_recall: 0.8928
# Epoch 19/30
# 992/992 [==============================] - 137s 138ms/step - loss: 0.2409 - accuracy: 0.9019 - precision: 0.8830 - recall: 0.8569 - val_loss: 0.1625 - val_accuracy: 0.9360 - val_precision: 0.9235 - val_recall: 0.8848
# Epoch 20/30
# 992/992 [==============================] - 137s 138ms/step - loss: 0.2402 - accuracy: 0.9021 - precision: 0.8848 - recall: 0.8553 - val_loss: 0.1601 - val_accuracy: 0.9365 - val_precision: 0.9241 - val_recall: 0.8857
# Epoch 21/30
# 992/992 [==============================] - 136s 137ms/step - loss: 0.2417 - accuracy: 0.9016 - precision: 0.8837 - recall: 0.8554 - val_loss: 0.1617 - val_accuracy: 0.9366 - val_precision: 0.9193 - val_recall: 0.8915
# Epoch 22/30
# 992/992 [==============================] - 138s 139ms/step - loss: 0.2418 - accuracy: 0.9016 - precision: 0.8826 - recall: 0.8567 - val_loss: 0.1611 - val_accuracy: 0.9365 - val_precision: 0.9184 - val_recall: 0.8921
# Epoch 23/30
# 992/992 [==============================] - 136s 137ms/step - loss: 0.2399 - accuracy: 0.9019 - precision: 0.8833 - recall: 0.8565 - val_loss: 0.1594 - val_accuracy: 0.9371 - val_precision: 0.9160 - val_recall: 0.8969
# Epoch 24/30
# 992/992 [==============================] - 140s 142ms/step - loss: 0.2406 - accuracy: 0.9016 - precision: 0.8823 - recall: 0.8571 - val_loss: 0.1608 - val_accuracy: 0.9362 - val_precision: 0.9214 - val_recall: 0.8879
# Epoch 25/30
# 992/992 [==============================] - 139s 140ms/step - loss: 0.2408 - accuracy: 0.9019 - precision: 0.8835 - recall: 0.8563 - val_loss: 0.1600 - val_accuracy: 0.9362 - val_precision: 0.9233 - val_recall: 0.8854
# Epoch 26/30
# 992/992 [==============================] - 136s 137ms/step - loss: 0.2397 - accuracy: 0.9027 - precision: 0.8837 - recall: 0.8584 - val_loss: 0.1593 - val_accuracy: 0.9367 - val_precision: 0.9153 - val_recall: 0.8965
# Epoch 27/30
# 992/992 [==============================] - 136s 137ms/step - loss: 0.2392 - accuracy: 0.9026 - precision: 0.8829 - recall: 0.8594 - val_loss: 0.1594 - val_accuracy: 0.9367 - val_precision: 0.9270 - val_recall: 0.8830
# Epoch 28/30
# 992/992 [==============================] - 135s 136ms/step - loss: 0.2395 - accuracy: 0.9027 - precision: 0.8843 - recall: 0.8577 - val_loss: 0.1625 - val_accuracy: 0.9367 - val_precision: 0.9275 - val_recall: 0.8823
# Epoch 29/30
# 992/992 [==============================] - 140s 141ms/step - loss: 0.2397 - accuracy: 0.9022 - precision: 0.8827 - recall: 0.8582 - val_loss: 0.1588 - val_accuracy: 0.9369 - val_precision: 0.9165 - val_recall: 0.8957
# Epoch 30/30
# 992/992 [==============================] - 139s 140ms/step - loss: 0.2391 - accuracy: 0.9023 - precision: 0.8830 - recall: 0.8583 - val_loss: 0.1606 - val_accuracy: 0.9363 - val_precision: 0.9271 - val_recall: 0.8817

# %%
total_label_count = 8
extended_model = extend_model(model_initial, 6, total_label_count)
extended_model.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 280)]                0         []
#
#  sourcecode_features (Input  [(None, 768)]                0         []
#  Layer)
#
#  embedding (Embedding)       (None, 280, 286)             9724000   ['input_1[0][0]']
#
#  codebert_dense_layer_1 (De  (None, 512)                  393728    ['sourcecode_features[0][0]']
#  nse)
#
#  bidirectional (Bidirection  (None, 256)                  424960    ['embedding[0][0]']
#  al)
#
#  codebert_bn_1 (BatchNormal  (None, 512)                  2048      ['codebert_dense_layer_1[0][0]
#  ization)                                                           ']
#
#  dropout (Dropout)           (None, 256)                  0         ['bidirectional[0][0]']
#
#  codebert_dropout_layer_1 (  (None, 512)                  0         ['codebert_bn_1[0][0]']
#  Dropout)
#
#  batch_normalization1 (Batc  (None, 256)                  1024      ['dropout[0][0]']
#  hNormalization)
#
#  codebert_dense_layer_2 (De  (None, 256)                  131328    ['codebert_dropout_layer_1[0][
#  nse)                                                               0]']
#
#  drop_out (Dropout)          (None, 256)                  0         ['batch_normalization1[0][0]']
#
#  codebert_bn_2 (BatchNormal  (None, 256)                  1024      ['codebert_dense_layer_2[0][0]
#  ization)                                                           ']
#
#  dense (Dense)               (None, 128)                  32896     ['drop_out[0][0]']
#
#  codebert_dropout_layer_2 (  (None, 256)                  0         ['codebert_bn_2[0][0]']
#  Dropout)
#
#  batch_normalization (Batch  (None, 128)                  512       ['dense[0][0]']
#  Normalization)
#
#  codebert_dense_layer_out (  (None, 128)                  32896     ['codebert_dropout_layer_2[0][
#  Dense)                                                             0]']
#
#  dropout_1 (Dropout)         (None, 128)                  0         ['batch_normalization[0][0]']
#
#  codebert_bn (BatchNormaliz  (None, 128)                  512       ['codebert_dense_layer_out[0][
#  ation)                                                             0]']
#
#  dense_1 (Dense)             (None, 128)                  16512     ['dropout_1[0][0]']
#
#  codebert_output (Dense)     (None, 8)                    1032      ['codebert_bn[0][0]']
#
#  dense_2 (Dense)             (None, 8)                    1032      ['dense_1[0][0]']
#
#  gnn_output (InputLayer)     [(None, 8)]                  0         []
#
#  concatenate_2 (Concatenate  (None, 24)                   0         ['codebert_output[0][0]',
#  )                                                                   'dense_2[0][0]',
#                                                                      'gnn_output[0][0]']
#
#  reshape_2 (Reshape)         (None, 24, 1)                0         ['concatenate_2[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 22, 64)               256       ['reshape_2[0][0]']
#
#  flatten_2 (Flatten)         (None, 1408)                 0         ['conv1d_2[0][0]']
#
#  dense_multilabel (Dense)    (None, 128)                  180352    ['flatten_2[0][0]']
#
#  drop_multilabel (Dropout)   (None, 128)                  0         ['dense_multilabel[0][0]']
#
#  reshape_extend (Reshape)    (None, 128)                  0         ['drop_multilabel[0][0]']
#
#  output_extended_labels (De  (None, 8)                    1032      ['reshape_extend[0][0]']
#  nse)
#
# ==================================================================================================
# Total params: 10945144 (41.75 MB)
# Trainable params: 1032 (4.03 KB)
# Non-trainable params: 10944112 (41.75 MB)
# __________________________________________________________________________________________________

# %%
extended_model.fit([X_train_source_8, X_train_opcode_8, gnn_train_outputs], y_train_8, epochs=30, batch_size=32, callbacks=[early_stopping])
# Out:
# Epoch 1/30
# 992/992 [==============================] - 111s 108ms/step - loss: 0.3306 - accuracy: 0.8590 - precision: 0.8252 - recall: 0.7321
# Epoch 2/30
# 992/992 [==============================] - 106s 107ms/step - loss: 0.2623 - accuracy: 0.8916 - precision: 0.8679 - recall: 0.7962
# Epoch 3/30
# 992/992 [==============================] - 110s 111ms/step - loss: 0.2560 - accuracy: 0.8931 - precision: 0.8661 - recall: 0.8037
# Epoch 4/30
# 992/992 [==============================] - 116s 117ms/step - loss: 0.2544 - accuracy: 0.8939 - precision: 0.8653 - recall: 0.8074
# Epoch 5/30
# 992/992 [==============================] - 116s 117ms/step - loss: 0.2531 - accuracy: 0.8939 - precision: 0.8643 - recall: 0.8088
# Epoch 6/30
# 992/992 [==============================] - 118s 119ms/step - loss: 0.2527 - accuracy: 0.8945 - precision: 0.8643 - recall: 0.8109
# Epoch 7/30
# 992/992 [==============================] - 120s 121ms/step - loss: 0.2525 - accuracy: 0.8945 - precision: 0.8638 - recall: 0.8115
# Epoch 8/30
# 992/992 [==============================] - 121s 122ms/step - loss: 0.2528 - accuracy: 0.8948 - precision: 0.8646 - recall: 0.8115
# Epoch 9/30
# 992/992 [==============================] - 121s 122ms/step - loss: 0.2518 - accuracy: 0.8948 - precision: 0.8646 - recall: 0.8117
# Epoch 10/30
# 992/992 [==============================] - 119s 120ms/step - loss: 0.2516 - accuracy: 0.8950 - precision: 0.8646 - recall: 0.8125
# Epoch 11/30
# 992/992 [==============================] - 119s 120ms/step - loss: 0.2524 - accuracy: 0.8950 - precision: 0.8654 - recall: 0.8115
# Epoch 12/30
# 992/992 [==============================] - 121s 122ms/step - loss: 0.2527 - accuracy: 0.8945 - precision: 0.8647 - recall: 0.8105
# Epoch 13/30
# 992/992 [==============================] - 116s 117ms/step - loss: 0.2517 - accuracy: 0.8951 - precision: 0.8662 - recall: 0.8107
# Epoch 14/30
# 992/992 [==============================] - 114s 115ms/step - loss: 0.2519 - accuracy: 0.8945 - precision: 0.8649 - recall: 0.8104
# Epoch 15/30
# 992/992 [==============================] - 114s 114ms/step - loss: 0.2520 - accuracy: 0.8946 - precision: 0.8644 - recall: 0.8113
# Epoch 16/30
# 992/992 [==============================] - 112s 113ms/step - loss: 0.2508 - accuracy: 0.8954 - precision: 0.8660 - recall: 0.8119
# Epoch 17/30
# 992/992 [==============================] - 111s 112ms/step - loss: 0.2519 - accuracy: 0.8949 - precision: 0.8650 - recall: 0.8116
# Epoch 18/30
# 992/992 [==============================] - 112s 113ms/step - loss: 0.2522 - accuracy: 0.8946 - precision: 0.8644 - recall: 0.8111
# Epoch 19/30
# 992/992 [==============================] - 113s 114ms/step - loss: 0.2510 - accuracy: 0.8953 - precision: 0.8657 - recall: 0.8118
# Epoch 20/30
# 992/992 [==============================] - 112s 112ms/step - loss: 0.2508 - accuracy: 0.8956 - precision: 0.8661 - recall: 0.8127
# Epoch 21/30
# 992/992 [==============================] - 115s 116ms/step - loss: 0.2514 - accuracy: 0.8953 - precision: 0.8650 - recall: 0.8128
# Epoch 22/30
# 992/992 [==============================] - 116s 117ms/step - loss: 0.2515 - accuracy: 0.8946 - precision: 0.8650 - recall: 0.8106
# Epoch 23/30
# 992/992 [==============================] - 117s 118ms/step - loss: 0.2510 - accuracy: 0.8954 - precision: 0.8660 - recall: 0.8121
# Epoch 24/30
# 992/992 [==============================] - 114s 115ms/step - loss: 0.2518 - accuracy: 0.8947 - precision: 0.8643 - recall: 0.8117
# Epoch 25/30
# 992/992 [==============================] - 113s 114ms/step - loss: 0.2512 - accuracy: 0.8951 - precision: 0.8653 - recall: 0.8120

# %%
extended_model.save('KLTN_6to8.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # 7 to 8

# %%
X_train_opcode_7, X_test_opcode_7, X_train_source_7, X_test_source_7, y_train_7, y_test_7, labels_dataset_7 = load_dataset(7)
# Out:
# Load Features codeBERT success!!
# Load Data for 7-Label MultiLabel success!!

# %%
initial_label_count = 7
model_initial = create_model_with_labels(initial_label_count, total_label_count=8)
model_initial.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 280)]                0         []
#
#  sourcecode_features (Input  [(None, 768)]                0         []
#  Layer)
#
#  embedding (Embedding)       (None, 280, 286)             9724000   ['input_1[0][0]']
#
#  codebert_dense_layer_1 (De  (None, 512)                  393728    ['sourcecode_features[0][0]']
#  nse)
#
#  bidirectional (Bidirection  (None, 256)                  424960    ['embedding[0][0]']
#  al)
#
#  codebert_bn_1 (BatchNormal  (None, 512)                  2048      ['codebert_dense_layer_1[0][0]
#  ization)                                                           ']
#
#  dropout (Dropout)           (None, 256)                  0         ['bidirectional[0][0]']
#
#  codebert_dropout_layer_1 (  (None, 512)                  0         ['codebert_bn_1[0][0]']
#  Dropout)
#
#  batch_normalization1 (Batc  (None, 256)                  1024      ['dropout[0][0]']
#  hNormalization)
#
#  codebert_dense_layer_2 (De  (None, 256)                  131328    ['codebert_dropout_layer_1[0][
#  nse)                                                               0]']
#
#  drop_out (Dropout)          (None, 256)                  0         ['batch_normalization1[0][0]']
#
#  codebert_bn_2 (BatchNormal  (None, 256)                  1024      ['codebert_dense_layer_2[0][0]
#  ization)                                                           ']
#
#  dense (Dense)               (None, 128)                  32896     ['drop_out[0][0]']
#
#  codebert_dropout_layer_2 (  (None, 256)                  0         ['codebert_bn_2[0][0]']
#  Dropout)
#
#  batch_normalization (Batch  (None, 128)                  512       ['dense[0][0]']
#  Normalization)
#
#  codebert_dense_layer_out (  (None, 128)                  32896     ['codebert_dropout_layer_2[0][
#  Dense)                                                             0]']
#
#  dropout_1 (Dropout)         (None, 128)                  0         ['batch_normalization[0][0]']
#
#  codebert_bn (BatchNormaliz  (None, 128)                  512       ['codebert_dense_layer_out[0][
#  ation)                                                             0]']
#
#  dense_1 (Dense)             (None, 128)                  16512     ['dropout_1[0][0]']
#
#  codebert_output (Dense)     (None, 8)                    1032      ['codebert_bn[0][0]']
#
#  dense_2 (Dense)             (None, 8)                    1032      ['dense_1[0][0]']
#
#  gnn_output (InputLayer)     [(None, 8)]                  0         []
#
#  concatenate_3 (Concatenate  (None, 24)                   0         ['codebert_output[0][0]',
#  )                                                                   'dense_2[0][0]',
#                                                                      'gnn_output[0][0]']
#
#  reshape_3 (Reshape)         (None, 24, 1)                0         ['concatenate_3[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 22, 64)               256       ['reshape_3[0][0]']
#
#  flatten_3 (Flatten)         (None, 1408)                 0         ['conv1d_3[0][0]']
#
#  dense_multilabel (Dense)    (None, 128)                  180352    ['flatten_3[0][0]']
#
#  drop_multilabel (Dropout)   (None, 128)                  0         ['dense_multilabel[0][0]']
#
#  output_initial_labels (Den  (None, 7)                    903       ['drop_multilabel[0][0]']
#  se)
#
# ==================================================================================================
# Total params: 10945015 (41.75 MB)
# Trainable params: 181511 (709.03 KB)
# Non-trainable params: 10763504 (41.06 MB)
# __________________________________________________________________________________________________

# %%
model_initial.fit([X_train_source_7, X_train_opcode_7, gnn_train_outputs], y_train_7, epochs=30, batch_size=32, validation_data=([X_test_source_7, X_test_opcode_7, gnn_test_outputs], y_test_7))
# Out:
# Epoch 1/30
# 992/992 [==============================] - 148s 146ms/step - loss: 0.2755 - accuracy: 0.8924 - precision: 0.8586 - recall: 0.8200 - val_loss: 0.1788 - val_accuracy: 0.9384 - val_precision: 0.9150 - val_recall: 0.8762
# Epoch 2/30
# 992/992 [==============================] - 146s 147ms/step - loss: 0.2495 - accuracy: 0.9019 - precision: 0.8672 - recall: 0.8418 - val_loss: 0.1721 - val_accuracy: 0.9387 - val_precision: 0.9059 - val_recall: 0.8879
# Epoch 3/30
# 992/992 [==============================] - 146s 147ms/step - loss: 0.2463 - accuracy: 0.9030 - precision: 0.8690 - recall: 0.8430 - val_loss: 0.1717 - val_accuracy: 0.9370 - val_precision: 0.9112 - val_recall: 0.8756
# Epoch 4/30
# 992/992 [==============================] - 144s 145ms/step - loss: 0.2448 - accuracy: 0.9036 - precision: 0.8703 - recall: 0.8436 - val_loss: 0.1681 - val_accuracy: 0.9393 - val_precision: 0.9065 - val_recall: 0.8895
# Epoch 5/30
# 992/992 [==============================] - 142s 143ms/step - loss: 0.2435 - accuracy: 0.9034 - precision: 0.8707 - recall: 0.8422 - val_loss: 0.1679 - val_accuracy: 0.9392 - val_precision: 0.9122 - val_recall: 0.8824
# Epoch 6/30
# 992/992 [==============================] - 142s 143ms/step - loss: 0.2428 - accuracy: 0.9032 - precision: 0.8710 - recall: 0.8413 - val_loss: 0.1626 - val_accuracy: 0.9390 - val_precision: 0.9140 - val_recall: 0.8795
# Epoch 7/30
# 992/992 [==============================] - 139s 140ms/step - loss: 0.2416 - accuracy: 0.9040 - precision: 0.8730 - recall: 0.8414 - val_loss: 0.1665 - val_accuracy: 0.9393 - val_precision: 0.9140 - val_recall: 0.8807
# Epoch 8/30
# 992/992 [==============================] - 150s 151ms/step - loss: 0.2401 - accuracy: 0.9043 - precision: 0.8749 - recall: 0.8399 - val_loss: 0.1601 - val_accuracy: 0.9404 - val_precision: 0.9173 - val_recall: 0.8808
# Epoch 9/30
# 992/992 [==============================] - 145s 146ms/step - loss: 0.2408 - accuracy: 0.9037 - precision: 0.8737 - recall: 0.8395 - val_loss: 0.1611 - val_accuracy: 0.9399 - val_precision: 0.9224 - val_recall: 0.8732
# Epoch 10/30
# 992/992 [==============================] - 140s 141ms/step - loss: 0.2396 - accuracy: 0.9040 - precision: 0.8750 - recall: 0.8388 - val_loss: 0.1594 - val_accuracy: 0.9395 - val_precision: 0.9176 - val_recall: 0.8773
# Epoch 11/30
# 992/992 [==============================] - 144s 145ms/step - loss: 0.2389 - accuracy: 0.9045 - precision: 0.8777 - recall: 0.8371 - val_loss: 0.1600 - val_accuracy: 0.9405 - val_precision: 0.9116 - val_recall: 0.8881
# Epoch 12/30
# 992/992 [==============================] - 141s 142ms/step - loss: 0.2381 - accuracy: 0.9038 - precision: 0.8767 - recall: 0.8362 - val_loss: 0.1580 - val_accuracy: 0.9396 - val_precision: 0.9183 - val_recall: 0.8768
# Epoch 13/30
# 992/992 [==============================] - 142s 144ms/step - loss: 0.2387 - accuracy: 0.9045 - precision: 0.8772 - recall: 0.8377 - val_loss: 0.1561 - val_accuracy: 0.9403 - val_precision: 0.9191 - val_recall: 0.8783
# Epoch 14/30
# 992/992 [==============================] - 142s 143ms/step - loss: 0.2377 - accuracy: 0.9052 - precision: 0.8789 - recall: 0.8381 - val_loss: 0.1561 - val_accuracy: 0.9397 - val_precision: 0.9171 - val_recall: 0.8787
# Epoch 15/30
# 992/992 [==============================] - 141s 142ms/step - loss: 0.2373 - accuracy: 0.9046 - precision: 0.8785 - recall: 0.8365 - val_loss: 0.1546 - val_accuracy: 0.9401 - val_precision: 0.9205 - val_recall: 0.8761
# Epoch 16/30
# 992/992 [==============================] - 144s 145ms/step - loss: 0.2370 - accuracy: 0.9048 - precision: 0.8790 - recall: 0.8365 - val_loss: 0.1563 - val_accuracy: 0.9396 - val_precision: 0.9172 - val_recall: 0.8780
# Epoch 17/30
# 992/992 [==============================] - 142s 144ms/step - loss: 0.2375 - accuracy: 0.9040 - precision: 0.8779 - recall: 0.8350 - val_loss: 0.1545 - val_accuracy: 0.9402 - val_precision: 0.9159 - val_recall: 0.8818
# Epoch 18/30
# 992/992 [==============================] - 146s 147ms/step - loss: 0.2375 - accuracy: 0.9045 - precision: 0.8784 - recall: 0.8363 - val_loss: 0.1537 - val_accuracy: 0.9401 - val_precision: 0.9193 - val_recall: 0.8774
# Epoch 19/30
# 992/992 [==============================] - 141s 142ms/step - loss: 0.2373 - accuracy: 0.9047 - precision: 0.8790 - recall: 0.8361 - val_loss: 0.1537 - val_accuracy: 0.9399 - val_precision: 0.9199 - val_recall: 0.8759
# Epoch 20/30
# 992/992 [==============================] - 146s 148ms/step - loss: 0.2362 - accuracy: 0.9046 - precision: 0.8786 - recall: 0.8363 - val_loss: 0.1540 - val_accuracy: 0.9397 - val_precision: 0.9191 - val_recall: 0.8761
# Epoch 21/30
# 992/992 [==============================] - 148s 149ms/step - loss: 0.2367 - accuracy: 0.9051 - precision: 0.8782 - recall: 0.8386 - val_loss: 0.1557 - val_accuracy: 0.9400 - val_precision: 0.9244 - val_recall: 0.8715
# Epoch 22/30
# 992/992 [==============================] - 154s 156ms/step - loss: 0.2359 - accuracy: 0.9047 - precision: 0.8791 - recall: 0.8362 - val_loss: 0.1536 - val_accuracy: 0.9401 - val_precision: 0.9190 - val_recall: 0.8780
# Epoch 23/30
# 992/992 [==============================] - 153s 154ms/step - loss: 0.2370 - accuracy: 0.9043 - precision: 0.8788 - recall: 0.8349 - val_loss: 0.1535 - val_accuracy: 0.9405 - val_precision: 0.9115 - val_recall: 0.8881
# Epoch 24/30
# 992/992 [==============================] - 149s 150ms/step - loss: 0.2362 - accuracy: 0.9042 - precision: 0.8782 - recall: 0.8357 - val_loss: 0.1555 - val_accuracy: 0.9402 - val_precision: 0.9215 - val_recall: 0.8752
# Epoch 25/30
# 992/992 [==============================] - 146s 147ms/step - loss: 0.2359 - accuracy: 0.9053 - precision: 0.8799 - recall: 0.8372 - val_loss: 0.1523 - val_accuracy: 0.9403 - val_precision: 0.9149 - val_recall: 0.8831
# Epoch 26/30
# 992/992 [==============================] - 143s 144ms/step - loss: 0.2340 - accuracy: 0.9051 - precision: 0.8793 - recall: 0.8370 - val_loss: 0.1532 - val_accuracy: 0.9399 - val_precision: 0.9201 - val_recall: 0.8759
# Epoch 27/30
# 992/992 [==============================] - 142s 143ms/step - loss: 0.2365 - accuracy: 0.9048 - precision: 0.8793 - recall: 0.8363 - val_loss: 0.1525 - val_accuracy: 0.9392 - val_precision: 0.9238 - val_recall: 0.8693
# Epoch 28/30
# 992/992 [==============================] - 145s 147ms/step - loss: 0.2345 - accuracy: 0.9050 - precision: 0.8789 - recall: 0.8374 - val_loss: 0.1529 - val_accuracy: 0.9394 - val_precision: 0.9199 - val_recall: 0.8743
# Epoch 29/30
# 992/992 [==============================] - 141s 142ms/step - loss: 0.2347 - accuracy: 0.9048 - precision: 0.8787 - recall: 0.8367 - val_loss: 0.1526 - val_accuracy: 0.9403 - val_precision: 0.9125 - val_recall: 0.8860
# Epoch 30/30
# 992/992 [==============================] - 140s 141ms/step - loss: 0.2347 - accuracy: 0.9049 - precision: 0.8775 - recall: 0.8388 - val_loss: 0.1522 - val_accuracy: 0.9407 - val_precision: 0.9187 - val_recall: 0.8804

# %%
total_label_count = 8
extended_model = extend_model(model_initial, 7, total_label_count)
extended_model.summary()
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 280)]                0         []
#
#  sourcecode_features (Input  [(None, 768)]                0         []
#  Layer)
#
#  embedding (Embedding)       (None, 280, 286)             9724000   ['input_1[0][0]']
#
#  codebert_dense_layer_1 (De  (None, 512)                  393728    ['sourcecode_features[0][0]']
#  nse)
#
#  bidirectional (Bidirection  (None, 256)                  424960    ['embedding[0][0]']
#  al)
#
#  codebert_bn_1 (BatchNormal  (None, 512)                  2048      ['codebert_dense_layer_1[0][0]
#  ization)                                                           ']
#
#  dropout (Dropout)           (None, 256)                  0         ['bidirectional[0][0]']
#
#  codebert_dropout_layer_1 (  (None, 512)                  0         ['codebert_bn_1[0][0]']
#  Dropout)
#
#  batch_normalization1 (Batc  (None, 256)                  1024      ['dropout[0][0]']
#  hNormalization)
#
#  codebert_dense_layer_2 (De  (None, 256)                  131328    ['codebert_dropout_layer_1[0][
#  nse)                                                               0]']
#
#  drop_out (Dropout)          (None, 256)                  0         ['batch_normalization1[0][0]']
#
#  codebert_bn_2 (BatchNormal  (None, 256)                  1024      ['codebert_dense_layer_2[0][0]
#  ization)                                                           ']
#
#  dense (Dense)               (None, 128)                  32896     ['drop_out[0][0]']
#
#  codebert_dropout_layer_2 (  (None, 256)                  0         ['codebert_bn_2[0][0]']
#  Dropout)
#
#  batch_normalization (Batch  (None, 128)                  512       ['dense[0][0]']
#  Normalization)
#
#  codebert_dense_layer_out (  (None, 128)                  32896     ['codebert_dropout_layer_2[0][
#  Dense)                                                             0]']
#
#  dropout_1 (Dropout)         (None, 128)                  0         ['batch_normalization[0][0]']
#
#  codebert_bn (BatchNormaliz  (None, 128)                  512       ['codebert_dense_layer_out[0][
#  ation)                                                             0]']
#
#  dense_1 (Dense)             (None, 128)                  16512     ['dropout_1[0][0]']
#
#  codebert_output (Dense)     (None, 8)                    1032      ['codebert_bn[0][0]']
#
#  dense_2 (Dense)             (None, 8)                    1032      ['dense_1[0][0]']
#
#  gnn_output (InputLayer)     [(None, 8)]                  0         []
#
#  concatenate_3 (Concatenate  (None, 24)                   0         ['codebert_output[0][0]',
#  )                                                                   'dense_2[0][0]',
#                                                                      'gnn_output[0][0]']
#
#  reshape_3 (Reshape)         (None, 24, 1)                0         ['concatenate_3[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 22, 64)               256       ['reshape_3[0][0]']
#
#  flatten_3 (Flatten)         (None, 1408)                 0         ['conv1d_3[0][0]']
#
#  dense_multilabel (Dense)    (None, 128)                  180352    ['flatten_3[0][0]']
#
#  drop_multilabel (Dropout)   (None, 128)                  0         ['dense_multilabel[0][0]']
#
#  reshape_extend (Reshape)    (None, 128)                  0         ['drop_multilabel[0][0]']
#
#  output_extended_labels (De  (None, 8)                    1032      ['reshape_extend[0][0]']
#  nse)
#
# ==================================================================================================
# Total params: 10945144 (41.75 MB)
# Trainable params: 1032 (4.03 KB)
# Non-trainable params: 10944112 (41.75 MB)
# __________________________________________________________________________________________________

# %%
extended_model.fit([X_train_source_8, X_train_opcode_8, gnn_train_outputs], y_train_8, epochs=30, batch_size=32, callbacks=[early_stopping])
# Out:
# Epoch 1/30
# 992/992 [==============================] - 119s 117ms/step - loss: 0.3319 - accuracy: 0.8552 - precision: 0.8131 - recall: 0.7348
# Epoch 2/30
# 992/992 [==============================] - 117s 118ms/step - loss: 0.2620 - accuracy: 0.8908 - precision: 0.8628 - recall: 0.7998
# Epoch 3/30
# 992/992 [==============================] - 117s 118ms/step - loss: 0.2578 - accuracy: 0.8923 - precision: 0.8620 - recall: 0.8061
# Epoch 4/30
# 992/992 [==============================] - 117s 118ms/step - loss: 0.2561 - accuracy: 0.8931 - precision: 0.8616 - recall: 0.8094
# Epoch 5/30
# 992/992 [==============================] - 114s 115ms/step - loss: 0.2563 - accuracy: 0.8929 - precision: 0.8611 - recall: 0.8094
# Epoch 6/30
# 992/992 [==============================] - 114s 115ms/step - loss: 0.2554 - accuracy: 0.8934 - precision: 0.8618 - recall: 0.8105
# Epoch 7/30
# 992/992 [==============================] - 116s 117ms/step - loss: 0.2558 - accuracy: 0.8928 - precision: 0.8615 - recall: 0.8086
# Epoch 8/30
# 992/992 [==============================] - 116s 117ms/step - loss: 0.2561 - accuracy: 0.8929 - precision: 0.8612 - recall: 0.8093
# Epoch 9/30
# 992/992 [==============================] - 123s 124ms/step - loss: 0.2561 - accuracy: 0.8927 - precision: 0.8607 - recall: 0.8092
# Epoch 10/30
# 992/992 [==============================] - 127s 128ms/step - loss: 0.2559 - accuracy: 0.8925 - precision: 0.8607 - recall: 0.8086
# Epoch 11/30
# 992/992 [==============================] - 124s 125ms/step - loss: 0.2548 - accuracy: 0.8936 - precision: 0.8619 - recall: 0.8108
# Epoch 12/30
# 992/992 [==============================] - 120s 120ms/step - loss: 0.2558 - accuracy: 0.8929 - precision: 0.8614 - recall: 0.8089
# Epoch 13/30
# 992/992 [==============================] - 119s 120ms/step - loss: 0.2550 - accuracy: 0.8936 - precision: 0.8621 - recall: 0.8105
# Epoch 14/30
# 992/992 [==============================] - 118s 119ms/step - loss: 0.2548 - accuracy: 0.8935 - precision: 0.8617 - recall: 0.8106
# Epoch 15/30
# 992/992 [==============================] - 119s 120ms/step - loss: 0.2557 - accuracy: 0.8928 - precision: 0.8606 - recall: 0.8097
# Epoch 16/30
# 992/992 [==============================] - 125s 126ms/step - loss: 0.2557 - accuracy: 0.8934 - precision: 0.8624 - recall: 0.8094

# %%
extended_model.save('Transfer_learning_7to8.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # Kiểm thử
